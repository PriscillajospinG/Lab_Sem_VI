# %%
# !pip install pytest

# %%
# %%writefile add.py
def add_numbers(a,b):
    return a+b
# Out:
# Overwriting add.py

# %%
# %%writefile tadd.py
from add import add_numbers

def test_p_nums():
    assert add_numbers(20,4) == 24
def test_n_nums():
    assert add_numbers(-2,-4) == -6
def test_m_nums():
    assert add_numbers(-20,4) == -16
def test_z_nums():
    assert add_numbers(0,4) == 4
# Out:
# Overwriting tadd.py

# %%
# !pytest -v tadd.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: langsmith-0.4.47, anyio-4.11.0, typeguard-4.4.4
# collected 4 items
#
# tadd.py::test_p_nums PASSED                                              [ 25%]
# tadd.py::test_n_nums PASSED                                              [ 50%]
# tadd.py::test_m_nums PASSED                                              [ 75%]
# tadd.py::test_z_nums PASSED                                              [100%]
#
# ============================== 4 passed in 0.02s ===============================

# %%
# %%writefile avg.py
def avg_numbers(a,b,n):
    return (a+b)/n
# Out:
# Overwriting avg.py

# %%
# %%writefile test_avg.py
from avg import avg_numbers
def test_nums():
    assert avg_numbers(20,4,2) == 12
# Out:
# Overwriting test_avg.py

# %%
# !pytest -v test_avg.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: langsmith-0.4.47, anyio-4.11.0, typeguard-4.4.4
# collected 1 item
#
# test_avg.py::test_nums PASSED                                            [100%]
#
# ============================== 1 passed in 0.01s ===============================

# %%
# %%writefile factorial.py
def factorial(n):
    if n < 0:
        raise ValueError("Negative numbers not allowed")
    if n == 0:
        return 1
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result
# Out:
# Writing factorial.py

# %%
# %%writefile tfactorial.py
import pytest
from factorial import factorial

def test_positive():
    assert factorial(5) == 120

def test_zero():
    assert factorial(0) == 1

def test_one():
    assert factorial(1) == 1

def test_negative():
    with pytest.raises(ValueError):
        factorial(-3)
# Out:
# Writing tfactorial.py

# %%
# !pytest -v tfactorial.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: langsmith-0.4.59, typeguard-4.4.4, anyio-4.12.0
# collected 4 items
#
# tfactorial.py::test_positive PASSED                                      [ 25%]
# tfactorial.py::test_zero PASSED                                          [ 50%]
# tfactorial.py::test_one PASSED                                           [ 75%]
# tfactorial.py::test_negative PASSED                                      [100%]
#
# ============================== 4 passed in 0.02s ===============================

# %%
# %%writefile palindrome.py
def is_palindrome(s):
    return s == s[::-1]
# Out:
# Writing palindrome.py

# %%
# %%writefile tpalindrome.py
from palindrome import is_palindrome

def test_odd_length():
    assert is_palindrome("madam") == True

def test_even_length():
    assert is_palindrome("abba") == True

def test_digits():
    assert is_palindrome("12321") == True

def test_special_char():
    assert is_palindrome("madam!") == False

def test_not_palindrome():
    assert is_palindrome("hello") == False
# Out:
# Writing tpalindrome.py

# %%
# !pytest -v tpalindrome.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: langsmith-0.4.59, typeguard-4.4.4, anyio-4.12.0
# collected 5 items
#
# tpalindrome.py::test_odd_length PASSED                                   [ 20%]
# tpalindrome.py::test_even_length PASSED                                  [ 40%]
# tpalindrome.py::test_digits PASSED                                       [ 60%]
# tpalindrome.py::test_special_char PASSED                                 [ 80%]
# tpalindrome.py::test_not_palindrome PASSED                               [100%]
#
# ============================== 5 passed in 0.02s ===============================
